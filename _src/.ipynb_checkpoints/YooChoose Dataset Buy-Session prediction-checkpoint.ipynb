# %% [markdown]
# Code-folding extension, run to enable visual shortening of source code for function definitions

# %% [markdown]
# Import required modules

# %%
import numpy as np
import tensorflow as tf
import os
import math
import sys
import importlib
from datetime import datetime
from datetime import timedelta

# Data preprocessing methods
import DataHandler 
from DataHandler import *
if (sys.version_info > (3, 0)):
    importlib.reload(DataHandler)
else:
    reload(DataHandler)

# Input object classes
import ModelInput
from ModelInput import *
if (sys.version_info > (3, 0)):
    importlib.reload(ModelInput)
else:
    reload(ModelInput)

# %% [markdown]
# Loading data:
#
#     Train data = 80% of all rows
#     Validation data = 10% of all rows
#     Test  data = 10% of all rows

# %%
# Set to True to create small sample dataset, otherwise False
use_sample = False
use_subset = False
subset_size = 10000

dir = os.getcwd()

filename_sample_clicks = os.path.join(dir, '..', 'data', 'yoochoose-clicks-sample.dat')
filename_sample_buys = os.path.join(dir, '..', 'data', 'yoochoose-buys-sample.dat')

filename_clicks = os.path.join(dir, '..', 'data', 'yoochoose-clicks_100k.dat')
filename_buys = os.path.join(dir, '..', 'data', 'yoochoose-buys_100k.dat')

filename_test = os.path.join(dir, '../data/yoochoose-test.dat')

if use_sample:
    print ('Working with test dataset')

    train_buys, valid_buys, test_buys = create_dataset_buys(filename_sample_buys)
    train_clicks, valid_clicks, test_clicks = create_dataset_clicks(filename_sample_clicks)

else:
    print ('Working with real dataset')

    all_buys, train_buys, valid_buys, test_buys = create_dataset_buys(filename_buys)
    train_clicks, valid_clicks, test_clicks = create_dataset_clicks(filename_clicks)

if use_subset:
    print ('Working with subset')

    train_buys = train_buys[:subset_size]
    train_clicks = train_clicks[:subset_size]
# Out:
# Working with real dataset
# Loading dataset of buy events
# Size of buys dataset: 100000
# Train size: 80000
# Validate size: 10000
# Test size: 10000
# Finished loading dataset
# Loading dataset of click events
# Size of clicks dataset: 100000
# Train size: 80000
# Valid size: 10000
# Test size: 10000
# Finished loading dataset

# %% [markdown]
# Preprocessing of data.
#
# Create train and test data consisting of:
#
#     Input vectors [0.33, 0.01, 1.62, 1.05, 0.66, 0.00, 1.00]
#     Output labels [0, 1] or [1, 0]

# %%
print ('-------  Creating input  ------- \n')

# Create input to the network
train_sessions = Session.create_sessions_from_clicks(train_clicks)
print('Created Sessions')
train_session_objects = SessionObject.create_session_object_list(train_sessions)
print('Created Session Objects')
train_vectors = SessionObject.create_input_vectors(train_session_objects, info=False)
print('Created Input Vectors')
train_labels = create_labels(all_buys, train_session_objects, info=False)
train_labels = reformat(train_labels)

# Balancing dataset because of incredible ratio of buy sessions and non-buy sessions
# Final ratio - 1:1
train_vectors, train_labels = oversample_dataset(train_vectors, train_labels, info=True)

train_batches_vectors = []
train_batches_labels = []
batch_size = 128

# Create training batches of vectors and labels
for index in range(0, len(train_vectors)/batch_size):
    train_batches_vectors.append(train_vectors[batch_size*index:batch_size*(index+1)])
    train_batches_labels.append(train_labels[batch_size*index:batch_size*(index+1)])
    
print ('Created train dataset\n')

valid_sessions = Session.create_sessions_from_clicks(valid_clicks)
valid_session_objects = SessionObject.create_session_object_list(valid_sessions)
valid_vectors = SessionObject.create_input_vectors(valid_session_objects, info=False)
valid_labels = create_labels(all_buys, valid_session_objects, info=False)
valid_labels = reformat(valid_labels)

# Balancing dataset because of incredible ratio of buy sessions and non-buy sessions
# Final ratio - 1:1
# valid_vectors, valid_labels = oversample_dataset(valid_vectors, valid_labels, info=True)
print ('Created validation dataset\n')

test_sessions = Session.create_sessions_from_clicks(test_clicks)
test_session_objects = SessionObject.create_session_object_list(test_sessions)
test_vectors = SessionObject.create_input_vectors(test_session_objects, info=False)
test_labels = create_labels(all_buys, test_session_objects, info=False)
test_labels = reformat(test_labels)
print ('Created test dataset\n')

print ('--------  Dimensions  -------- \n')

print (' Train dataset:        %d %d   ' % (len(train_vectors), len(train_vectors[0])))
print (' Train labels:         %d %d \n' % (len( train_labels), len(train_labels [0])))

print (' Validation dataset:   %d %d   ' % (len(valid_vectors), len(valid_vectors[0])))
print (' Validation labels:    %d %d \n' % (len( valid_labels), len( valid_labels[0])))

print (' Test dataset:         %d %d   ' % (len(test_vectors),  len( test_vectors[0])))
print (' Test labels:          %d %d \n' % (len( test_labels),  len(  test_labels[0])))
# Out:
# -------  Creating input  -------
#
# Currently iterating through index 0
# Currently iterating through index 25000
# Currently iterating through index 50000
# Currently iterating through index 75000
# Created 5000 sessions
#
# Created 10000 sessions
#
# Created 15000 sessions
#
# Created 20000 sessions
#
# Created Sessions
# Created Session Objects
# Created 20125 input vectors from sessions
#
# Created Input Vectors
#
# Balanced to :
# 18905 buy sessions
# 18824 non-buy sessions
# 37729 total sessions
#
# Created train dataset
#
# Currently iterating through index 0
# Created 2605 input vectors from sessions
#
# Created validation dataset
#
# Currently iterating through index 0
# Created 2563 input vectors from sessions
#
# Created test dataset
#
# --------  Dimensions  --------
#
#  Train dataset:        37729 9
#  Train labels:         37729 2
#
#  Validation dataset:   2605 9
#  Validation labels:    2605 2
#
#  Test dataset:         2563 9
#  Test labels:          2563 2

# %% [markdown]
# Graph for network to be run by session.

# %%
graph = tf.Graph()
with graph.as_default():    
    
    # Variables.
    num_of_labels = 2
    learning_rate = 0.001
    hidden_size = 128
    
    # Input data. For the training data, use a placeholder that will be fed at run time with a training minibatch
    tf_train_vectors = tf.placeholder(tf.float32, shape=(batch_size, len(train_vectors[0])))
    tf_train_labels = tf.placeholder(tf.int32, shape=(batch_size, len(train_labels[0])))
    tf_valid_vectors = tf.constant(valid_vectors)
    tf_test_vectors = tf.constant(test_vectors)
    
    weights_h1 = tf.Variable(tf.truncated_normal([len(train_vectors[0]), hidden_size]))
    biases_h1 = tf.Variable(tf.zeros([hidden_size]))
    h1 = tf.nn.relu(tf.matmul(tf_train_vectors, weights_h1) + biases_h1)
    
    weights = tf.Variable(tf.truncated_normal([hidden_size, num_of_labels]))
    biases = tf.Variable(tf.zeros([num_of_labels]))
    
    # Training computation
    logits = tf.matmul(h1, weights) + biases
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
    #optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(
        tf.matmul(
            tf.nn.relu(
                tf.matmul(tf_valid_vectors, weights_h1) + biases_h1), weights) + biases)
    test_prediction = tf.nn.softmax(
        tf.matmul(
            tf.nn.relu(
                tf.matmul(tf_test_vectors, weights_h1) + biases_h1), weights) + biases)

# %% [markdown]
# Execute session and get results of train and test datasets
#
# Each batch should (in theory):
# * Increase the accuracy
# * Decrease the loss
#
# After finishing all batches, test dataset is ran through network

# %%
with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print("Initialized")
    
    last_validation_accuracy = 0.0
    
    stop_training = 0
    print len(train_batches_vectors)
    while stop_training < 3:
        for batch_index in range(len(train_batches_vectors)):
            # Generate a batch.
            batch_vectors = train_batches_vectors[batch_index]
            batch_labels = train_batches_labels[batch_index]

            # Feed the dictionary and start training
            feed_dict = {tf_train_vectors : batch_vectors, tf_train_labels : batch_labels}

            _, l, predictions = session.run(
                [optimizer, loss, train_prediction],
                feed_dict=feed_dict
            )

            #print("Batch loss at batch %d: %f" % (batch_index, l))
            #print("Batch accuracy: %.1f%%" % 
            #      accuracy(predictions, batch_labels))

            print("Validate accuracy: %.1f%%\n" % 
                  accuracy(valid_prediction.eval(), valid_labels, precision_print=False))
#             with open("validations.txt", "a") as myfile:
#                 textfloat = accuracy(valid_prediction.eval(), valid_labels, precision_print=False)
#                 myfile.write("%.3f\n" % textfloat)
        
        validation_accuracy = accuracy(
            valid_prediction.eval(), valid_labels, precision_print=True)
        
        # Count the difference of validation set accuracy 
        diff = validation_accuracy - last_validation_accuracy
        if diff < 1.0:
            stop_training +=1
            print('Accuracy improvement only %.3f, stop training increased to %d' % (diff, stop_training))
        else:
            print('Stop training reset')
            stop_training = 0
        
        last_validation_accuracy = validation_accuracy
            
    print("Test accuracy: %.1f%%" % 
          accuracy(test_prediction.eval(), test_labels, precision_print=True))
# Out:
# Initialized
# 294
# Validate accuracy: 79.5%
#
# Validate accuracy: 76.3%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 65.8%
#
# Validate accuracy: 58.0%
#
# Validate accuracy: 45.0%
#
# Validate accuracy: 43.1%
#
# Validate accuracy: 44.1%
#
# Validate accuracy: 46.2%
#
# Validate accuracy: 49.7%
#
# Validate accuracy: 59.8%
#
# Validate accuracy: 63.3%
#
# Validate accuracy: 68.1%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.8%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 75.3%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 68.0%
#
# Validate accuracy: 67.2%
#
# Validate accuracy: 65.7%
#
# Validate accuracy: 65.0%
#
# Validate accuracy: 64.6%
#
# Validate accuracy: 64.8%
#
# Validate accuracy: 66.0%
#
# Validate accuracy: 66.5%
#
# Validate accuracy: 66.9%
#
# Validate accuracy: 67.1%
#
# Validate accuracy: 67.2%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 69.2%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 67.5%
#
# Validate accuracy: 66.2%
#
# Validate accuracy: 66.5%
#
# Validate accuracy: 66.9%
#
# Validate accuracy: 68.0%
#
# Validate accuracy: 69.3%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 67.5%
#
# Validate accuracy: 67.5%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 68.2%
#
# Validate accuracy: 68.2%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 68.8%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 75.1%
#
# Validate accuracy: 75.1%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 75.7%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 75.1%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 67.1%
#
# Validate accuracy: 65.4%
#
# Validate accuracy: 64.3%
#
# Validate accuracy: 64.8%
#
# Validate accuracy: 66.5%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 75.7%
#
# Validate accuracy: 75.7%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 66.1%
#
# Validate accuracy: 65.4%
#
# Validate accuracy: 66.7%
#
# Validate accuracy: 69.2%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 76.4%
#
# Validate accuracy: 77.2%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 77.6%
#
# Validate accuracy: 77.2%
#
# Validate accuracy: 76.9%
#
# Validate accuracy: 76.1%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 69.7%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 69.5%
#
# Validate accuracy: 69.1%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 69.1%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 75.4%
#
# Validate accuracy: 75.0%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 68.2%
#
# Validate accuracy: 67.7%
#
# Validate accuracy: 67.9%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 68.7%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 69.1%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 73.5%
#
# True positive = 143
# True negative = 1771
# False positive = 652
# False negative = 39
# Stop training reset
# Validate accuracy: 74.5%
#
# Validate accuracy: 75.8%
#
# Validate accuracy: 76.0%
#
# Validate accuracy: 75.5%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 75.3%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 69.3%
#
# Validate accuracy: 68.5%
#
# Validate accuracy: 68.1%
#
# Validate accuracy: 68.4%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 68.5%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 69.5%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 67.7%
#
# Validate accuracy: 66.6%
#
# Validate accuracy: 67.7%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 68.4%
#
# Validate accuracy: 66.6%
#
# Validate accuracy: 66.6%
#
# Validate accuracy: 66.4%
#
# Validate accuracy: 67.2%
#
# Validate accuracy: 68.4%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 75.5%
#
# Validate accuracy: 79.0%
#
# Validate accuracy: 80.3%
#
# Validate accuracy: 81.7%
#
# Validate accuracy: 83.6%
#
# Validate accuracy: 83.6%
#
# Validate accuracy: 82.9%
#
# Validate accuracy: 80.8%
#
# Validate accuracy: 78.3%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 69.2%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 76.2%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 77.3%
#
# Validate accuracy: 77.2%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.5%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 76.9%
#
# Validate accuracy: 78.4%
#
# Validate accuracy: 81.7%
#
# Validate accuracy: 82.3%
#
# Validate accuracy: 81.9%
#
# Validate accuracy: 79.3%
#
# Validate accuracy: 79.0%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 77.5%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 77.3%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 79.8%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 66.6%
#
# Validate accuracy: 65.4%
#
# Validate accuracy: 66.0%
#
# Validate accuracy: 67.8%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 78.1%
#
# Validate accuracy: 83.0%
#
# Validate accuracy: 85.3%
#
# Validate accuracy: 85.6%
#
# Validate accuracy: 85.6%
#
# Validate accuracy: 85.0%
#
# Validate accuracy: 82.1%
#
# Validate accuracy: 80.0%
#
# Validate accuracy: 76.4%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 68.8%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 75.8%
#
# Validate accuracy: 78.5%
#
# Validate accuracy: 78.7%
#
# Validate accuracy: 79.9%
#
# Validate accuracy: 80.2%
#
# Validate accuracy: 81.1%
#
# Validate accuracy: 79.7%
#
# Validate accuracy: 76.4%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 69.5%
#
# Validate accuracy: 69.1%
#
# Validate accuracy: 69.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 75.0%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 75.9%
#
# Validate accuracy: 77.4%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 79.5%
#
# Validate accuracy: 78.5%
#
# Validate accuracy: 76.0%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.8%
#
# True positive = 144
# True negative = 1778
# False positive = 645
# False negative = 38
# Accuracy improvement only 0.307, stop training increased to 1
# Validate accuracy: 74.2%
#
# Validate accuracy: 78.3%
#
# Validate accuracy: 78.4%
#
# Validate accuracy: 78.0%
#
# Validate accuracy: 77.1%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 76.5%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 75.8%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 75.5%
#
# Validate accuracy: 75.1%
#
# Validate accuracy: 76.0%
#
# Validate accuracy: 76.2%
#
# Validate accuracy: 75.8%
#
# Validate accuracy: 75.6%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.5%
#
# Validate accuracy: 69.4%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 77.4%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 75.7%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 68.2%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 68.3%
#
# Validate accuracy: 69.0%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 76.9%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 78.6%
#
# Validate accuracy: 79.7%
#
# Validate accuracy: 83.7%
#
# Validate accuracy: 83.8%
#
# Validate accuracy: 82.5%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 75.3%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 75.5%
#
# Validate accuracy: 76.5%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 76.8%
#
# Validate accuracy: 76.4%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 75.7%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.4%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 79.5%
#
# Validate accuracy: 81.2%
#
# Validate accuracy: 81.3%
#
# Validate accuracy: 81.3%
#
# Validate accuracy: 80.0%
#
# Validate accuracy: 79.6%
#
# Validate accuracy: 79.2%
#
# Validate accuracy: 77.6%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 78.5%
#
# Validate accuracy: 79.3%
#
# Validate accuracy: 79.4%
#
# Validate accuracy: 78.5%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 69.3%
#
# Validate accuracy: 67.0%
#
# Validate accuracy: 66.0%
#
# Validate accuracy: 66.7%
#
# Validate accuracy: 68.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 79.0%
#
# Validate accuracy: 80.5%
#
# Validate accuracy: 84.5%
#
# Validate accuracy: 86.2%
#
# Validate accuracy: 86.4%
#
# Validate accuracy: 83.0%
#
# Validate accuracy: 79.6%
#
# Validate accuracy: 78.4%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 69.3%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 77.2%
#
# Validate accuracy: 76.0%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 75.0%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 71.0%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 76.9%
#
# Validate accuracy: 77.5%
#
# Validate accuracy: 77.4%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 78.4%
#
# Validate accuracy: 77.8%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 69.8%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 76.2%
#
# Validate accuracy: 76.4%
#
# Validate accuracy: 76.6%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 77.6%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 77.8%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.8%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.5%
#
# True positive = 145
# True negative = 1797
# False positive = 626
# False negative = 37
# Accuracy improvement only 0.768, stop training increased to 2
# Validate accuracy: 74.8%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 76.5%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.8%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 75.1%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.8%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 69.9%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 74.8%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 68.6%
#
# Validate accuracy: 68.5%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 70.0%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 78.3%
#
# Validate accuracy: 78.6%
#
# Validate accuracy: 78.9%
#
# Validate accuracy: 79.9%
#
# Validate accuracy: 80.2%
#
# Validate accuracy: 79.6%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 77.3%
#
# Validate accuracy: 75.5%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.5%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 77.1%
#
# Validate accuracy: 77.5%
#
# Validate accuracy: 77.5%
#
# Validate accuracy: 75.3%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 75.0%
#
# Validate accuracy: 75.6%
#
# Validate accuracy: 75.8%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 71.2%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 70.9%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 70.7%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 72.3%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 77.6%
#
# Validate accuracy: 79.4%
#
# Validate accuracy: 80.5%
#
# Validate accuracy: 81.0%
#
# Validate accuracy: 80.8%
#
# Validate accuracy: 79.9%
#
# Validate accuracy: 79.4%
#
# Validate accuracy: 78.2%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 72.1%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 78.8%
#
# Validate accuracy: 75.2%
#
# Validate accuracy: 73.8%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 69.1%
#
# Validate accuracy: 67.3%
#
# Validate accuracy: 66.5%
#
# Validate accuracy: 67.1%
#
# Validate accuracy: 68.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 78.0%
#
# Validate accuracy: 79.9%
#
# Validate accuracy: 81.0%
#
# Validate accuracy: 82.6%
#
# Validate accuracy: 82.8%
#
# Validate accuracy: 80.5%
#
# Validate accuracy: 79.3%
#
# Validate accuracy: 78.3%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 70.3%
#
# Validate accuracy: 69.6%
#
# Validate accuracy: 70.2%
#
# Validate accuracy: 71.5%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 74.1%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.9%
#
# Validate accuracy: 75.0%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.3%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.5%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.4%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.2%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.1%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 71.6%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 74.2%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 77.8%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 78.0%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 76.9%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 70.1%
#
# Validate accuracy: 70.6%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 72.6%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 76.0%
#
# Validate accuracy: 76.7%
#
# Validate accuracy: 77.0%
#
# Validate accuracy: 77.5%
#
# Validate accuracy: 77.9%
#
# Validate accuracy: 77.7%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 72.7%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.0%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 70.8%
#
# Validate accuracy: 71.1%
#
# Validate accuracy: 71.3%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 73.4%
#
# Validate accuracy: 74.4%
#
# Validate accuracy: 74.7%
#
# Validate accuracy: 74.6%
#
# Validate accuracy: 74.5%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.3%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.9%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.6%
#
# Validate accuracy: 73.9%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 73.7%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 73.0%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.2%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 71.8%
#
# Validate accuracy: 71.7%
#
# Validate accuracy: 71.9%
#
# Validate accuracy: 72.4%
#
# Validate accuracy: 72.8%
#
# Validate accuracy: 73.5%
#
# Validate accuracy: 74.0%
#
# Validate accuracy: 74.6%
#
# True positive = 146
# True negative = 1797
# False positive = 626
# False negative = 36
# Accuracy improvement only 0.038, stop training increased to 3
# True positive = 129
# True negative = 1775
# False positive = 609
# False negative = 50
# Test accuracy: 74.3%
